# %% [markdown]
# #Use matplotlib to plot the following equation:
#
# #y = x^2 - x + 2

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %matplotlib inline
x = range(-50,50)
y = [((n ** 2) - n + 2) for n in x]

plt.plot(x, y)
plt.text(3.5,-10, 'origin', fontsize = 10, color = '#333333')
# Out:
# Text(3.5, -10, 'origin')

# %% [markdown]
# # Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# #y = x ** .05
# #y = x ** 3
# #y = 2 ** x
# #y = 1/(x + 1)

# %%
x = range(0,64)

y = [n ** 0.5 for n in x]

plt.plot(x, y)

plt.text(0.1,0, 'origin', fontsize = 10, color = '#444444')
# Out:
# Text(0.1, 0, 'origin')

# %%
x = range(-8,8)
y = [n ** 3 for n in x]

plt.plot(x, y)
plt.text(0.1,-15, 'origin', fontsize = 10, color = 'r')
plt.title('$y = x^3$', fontsize = 20)
plt.xlabel('$x$', fontsize = 20)
plt.ylabel('$x^3$', fontsize = 20)
# Out:
# Text(0, 0.5, '$x^3$')

# %%
x = np.linspace(0,10)
y = [2 ** n for n in x]


plt.plot(x, y)
plt.text(0.25,0, 'origin', fontsize = 10, color = 'r')
plt.title('$y = 2^x$', fontsize = 20)
plt.xlabel('$x$', fontsize = 20)
plt.ylabel('$2^x$', fontsize = 20)
# Out:
# Text(0, 0.5, '$2^x$')

# %%
x1 = np.setdiff1d(np.linspace(-11,-1,50), [-1])
x2 = np.setdiff1d(np.linspace(-1,10,50), [-1])
y1 = [(1/(n + 1)) for n in x1]
y2 = [(1/(n + 1)) for n in x2]
x3 = -1
y3 = [n for n in x3]


plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)

plt.text(0,0, 'origin', fontsize = 10, color = 'purple')
plt.title('$y = 1/(x + 1)$', fontsize = 20)
plt.grid(True, ls = '--')
plt.xlabel('$x$', fontsize = 20)
plt.ylabel('$1/(x + 1)$', fontsize = 20)
# Out:
# Text(0, 0.5, '$1/(x + 1)$')

# %%
x =[(x * 0.5) for x in range(0,16)]

y1 = [(n ** 0.5) for n in x]
y2 = [(n ** 3) for n in x]
y3 = [(2 ** n) for n in x]
y4 = [(1/(n + 1)) for n in x]

plt.figure(figsize = (12,6))

plt.subplot(2,2,1)
plt.plot(x, y1)

plt.subplot(2,2,2)
plt.plot(x, y2)

plt.subplot(2,2,3)
plt.plot(x, y3)

plt.subplot(2,2,4)
plt.plot(x, y4)

plt.tight_layout()
